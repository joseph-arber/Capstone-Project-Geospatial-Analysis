# %% [markdown]
# # IBM Capstone Project
#
# ## Data Acquistion
# The first phase of the project is to acquire all of the data that is needed for this project. The initial data required can be broken down into three separate data sets:
#
# 1. The FourSquare Top restaurant/cafe venues to visit in London
# 2. For each of the Top Site get a list of up restaurants in the surrounding area
# 3. The UK Government London Borough Income Level Dataset for the last Year

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import json 
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
from bs4 import BeautifulSoup
from urllib.request import urlopen
import ssl
import csv

from geopy.geocoders import Nominatim 
# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# /Users/joseph_arber/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Libraries imported.

# %% [markdown]
# ## Exploring City Data with the Four Square API
#
# ## Where is the best place to open a restuarant in London?
#
# Where in London would it be best to open a new restuarant?
#
# This notebook leverages the four square API to explore neighborhood's in London. To explore this problem we need to segment London neigborhood data the data appropriatley. This entails segmenting by the average income of an area, what types of restuarants are popular (historically), and by how many restuarants there are in an area. We can then map the restaurants by location (latitude and longtitude) and then segment the restuarants by type. In this analysis the following questions will be answered; what restuarants recieve the best reviews? what restuarants are most popular, and what part of london are they in? Is there a type of restaurant that is consistently more popular than others?
#
# **Business Problem:**
# This analysis will help anyone that wants to open up a restaurant in London and wants to know if it is a viable option where they intend on opening.

# %% [markdown]
# ### Four square Top Restuarant Venues in London

# %%
# Get longitude and latitude for London
address = 'London, London'

geolocator = Nominatim(user_agent="london_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of London is 51.5073219, -0.1276474.

# %%
# Set up Foursquare
CLIENT_ID = 'K2D5QVKQ0QPUPIKECQU2JIB3CHVFT4ZMTJQC5WVTRNYTDD5Z'
CLIENT_SECRET = '5ZVFLDC04W0W5SHCBZ11MDRG0MELPIER3QIFUOAWFAIZKJNK'
VERSION = '20200808' # Foursquare API version
LIMIT = 500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: K2D5QVKQ0QPUPIKECQU2JIB3CHVFT4ZMTJQC5WVTRNYTDD5Z
# CLIENT_SECRET:5ZVFLDC04W0W5SHCBZ11MDRG0MELPIER3QIFUOAWFAIZKJNK

# %% [markdown]
# **Do not run code unless process below does not work...**

# %%
# Use the Requests get method to request the top sites in Chicago
page = requests.get(
    "https://foursquare.com/explore?cat=topPicks&mode=url&near=London%2C%20Greater%20London%2C%20United%20Kingdom&nearGeoId=72057594040571679")

# Convert the HTML response into a BeautifulSoup Object
soup = BeautifulSoup(page.content, 'html.parser')

# Use the BeautifulSoup find_all method to extract each top site venue details.
top_venues = soup.find_all('div', class_='venueDetails')

# %%
search_query = 'Gym'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Gym .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=K2D5QVKQ0QPUPIKECQU2JIB3CHVFT4ZMTJQC5WVTRNYTDD5Z&client_secret=5ZVFLDC04W0W5SHCBZ11MDRG0MELPIER3QIFUOAWFAIZKJNK&ll=51.5073219,-0.1276474&v=20200808&query=Gym&radius=5000&limit=500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed8cb2e618f43001bce25da'},
#  'response': {'venues': [{'id': '55118ea6498e10c0a61edfa4',
#     'name': 'The Gym London Charing Cross',
#     'location': {'address': '17-21 Northumberland Ave',
#      'lat': 51.50701872318441,
#      'lng': -0.12476041859239369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50701872318441,
#        'lng': -0.12476041859239369}],
#      'distance': 202,
#      'postalCode': 'WC2N 5EA',
#      'cc': 'GB',
#      'city': 'City of London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['17-21 Northumberland Ave',
#       'City of London',
#       'Greater London',
#       'WC2N 5EA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '503a6e8be4b0bd2ec5157d9b',
#     'name': 'ESPA Life Gym',
#     'location': {'address': '10 Whitehall Pl',
#      'lat': 51.50631843415083,
#      'lng': -0.12464761734008789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50631843415083,
#        'lng': -0.12464761734008789}],
#      'distance': 235,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 Whitehall Pl',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5881e9efcc5b6a08df5a8768',
#     'name': 'Radisson Blu Gym',
#     'location': {'address': '31-36 Leicester Sq',
#      'lat': 51.50995,
#      'lng': -0.12987256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50995,
#        'lng': -0.12987256}],
#      'distance': 330,
#      'postalCode': 'WC2H 7LH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['31-36 Leicester Sq',
#       'London',
#       'Greater London',
#       'WC2H 7LH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '56fe22b0498ef2d2226413fb',
#     'name': 'FIT (W Hotel Gym)',
#     'location': {'lat': 51.51002945140006,
#      'lng': -0.13139774041125615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51002945140006,
#        'lng': -0.13139774041125615}],
#      'distance': 397,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London', 'Greater London', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4bfc141da118a59336ee6db6',
#     'name': 'The Gym',
#     'location': {'address': '30 The Piazza London WC2E 8BE',
#      'lat': 51.51186222602245,
#      'lng': -0.12195035778693862,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51186222602245,
#        'lng': -0.12195035778693862}],
#      'distance': 641,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['30 The Piazza London WC2E 8BE',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4f057f256c25095786d949e4',
#     'name': 'The Gym @ LikeMinds Club',
#     'location': {'address': 'Northumberland Ave',
#      'lat': 51.5073187453107,
#      'lng': -0.12748897004867576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5073187453107,
#        'lng': -0.12748897004867576}],
#      'distance': 10,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Northumberland Ave',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4ae4991ff964a520259c21e3',
#     'name': 'Nuffield Health Fitness & Wellbeing Gym',
#     'location': {'address': '9 Endell Street',
#      'lat': 51.51415625004893,
#      'lng': -0.12390816109064977,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51415625004893,
#        'lng': -0.12390816109064977}],
#      'distance': 803,
#      'postalCode': 'WC2H 9SA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Endell Street',
#       'London',
#       'Greater London',
#       'WC2H 9SA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '54c89520498e5d7951c9dd48',
#     'name': 'The May Fair Gym',
#     'location': {'address': 'The May Fair Hotel',
#      'crossStreet': 'Stratton St',
#      'lat': 51.508482961330806,
#      'lng': -0.14430483879778505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.508482961330806,
#        'lng': -0.14430483879778505}],
#      'distance': 1161,
#      'postalCode': 'W1J 8LT',
#      'cc': 'GB',
#      'city': 'Mayfair',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['The May Fair Hotel (Stratton St)',
#       'Mayfair',
#       'Greater London',
#       'W1J 8LT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '518cae33498e8c38baca3946',
#     'name': 'Lansdowne Club Gym & Pool',
#     'location': {'address': '9 Fitzmaurice Place',
#      'lat': 51.50830561713405,
#      'lng': -0.1452734054068475,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50830561713405,
#        'lng': -0.1452734054068475}],
#      'distance': 1226,
#      'postalCode': 'WIJ 5JD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Fitzmaurice Place',
#       'London',
#       'Greater London',
#       'WIJ 5JD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '580629ca38fa9251426bce25',
#     'name': 'The Belmont Gym',
#     'location': {'address': '1st. Floor, Embassy Garden Residence',
#      'crossStreet': 'Nine Elms Lane',
#      'lat': 51.482081,
#      'lng': -0.1345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.482081,
#        'lng': -0.1345}],
#      'distance': 2849,
#      'postalCode': 'SW8',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1st. Floor, Embassy Garden Residence (Nine Elms Lane)',
#       'London',
#       'Greater London',
#       'SW8',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4feae9c464a4fa28dce56e53',
#     'name': 'The Gym',
#     'location': {'address': '195-203 Waterloo Rd, Barons Pl',
#      'lat': 51.50073064127175,
#      'lng': -0.10709910660258051,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50073064127175,
#        'lng': -0.10709910660258051}],
#      'distance': 1601,
#      'postalCode': 'SE1 8UX',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['195-203 Waterloo Rd, Barons Pl',
#       'London',
#       'Greater London',
#       'SE1 8UX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4b83313bf964a520c1fc30e3',
#     'name': 'The Gym',
#     'location': {'address': '6A St. George Wharf',
#      'crossStreet': 'Wandsworth Rd',
#      'lat': 51.48530506481089,
#      'lng': -0.12624354692889028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48530506481089,
#        'lng': -0.12624354692889028}],
#      'distance': 2452,
#      'postalCode': 'SW8 2LE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['6A St. George Wharf (Wandsworth Rd)',
#       'London',
#       'Greater London',
#       'SW8 2LE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4c48029c0f5aa593a2d67f76',
#     'name': 'Regent Gym',
#     'location': {'address': '309 Regent St',
#      'lat': 51.51692587106962,
#      'lng': -0.14262820142416596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51692587106962,
#        'lng': -0.14262820142416596}],
#      'distance': 1490,
#      'postalCode': 'W1B 2UW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['309 Regent St',
#       'London',
#       'Greater London',
#       'W1B 2UW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '54446d45498ef5d7f4f4cfcf',
#     'name': 'Club Quarters Gym',
#     'location': {'lat': 51.5069665287522,
#      'lng': -0.1260475925254104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5069665287522,
#        'lng': -0.1260475925254104}],
#      'distance': 117,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4ba5fcadf964a520e82c39e3',
#     'name': 'The Gym',
#     'location': {'address': '332-334 Walworth Rd',
#      'lat': 51.48581815433415,
#      'lng': -0.09418714812698266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48581815433415,
#        'lng': -0.09418714812698266}],
#      'distance': 3332,
#      'postalCode': 'SE17 2NA',
#      'cc': 'GB',
#      'city': 'East Walworth',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['332-334 Walworth Rd',
#       'East Walworth',
#       'Greater London',
#       'SE17 2NA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '551e56e2498e16bdb3df38c3',
#     'name': 'The Gym Charing Cross',
#     'location': {'address': '17-21 Northumberland Avenue',
#      'lat': 51.50704192570248,
#      'lng': -0.12486453814637305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50704192570248,
#        'lng': -0.12486453814637305}],
#      'distance': 195,
#      'postalCode': 'W C2N',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['17-21 Northumberland Avenue',
#       'London',
#       'Greater London',
#       'W C2N',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '50da22c4e4b0be098804c1db',
#     'name': 'Park Plaza Gym',
#     'location': {'address': '239 Vauxhall Bridge Rd',
#      'lat': 51.49412316413798,
#      'lng': -0.14167368636697214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49412316413798,
#        'lng': -0.14167368636697214}],
#      'distance': 1761,
#      'postalCode': 'SW1V 1EQ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['239 Vauxhall Bridge Rd',
#       'London',
#       'Greater London',
#       'SW1V 1EQ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5d7b8e3725670800086cdd9c',
#     'name': 'Goldman Sachs Gym',
#     'location': {'address': 'Plumtree Court',
#      'lat': 51.516312,
#      'lng': -0.105678,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.516312,
#        'lng': -0.105678}],
#      'distance': 1821,
#      'postalCode': 'EC4A 4AU',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Plumtree Court',
#       'London',
#       'Greater London',
#       'EC4A 4AU',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4adc54a0f964a520bc2b21e3',
#     'name': 'Gymbox',
#     'location': {'address': "42 - 49 St Martin's Lane",
#      'lat': 51.5104680522224,
#      'lng': -0.1268028951415381,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5104680522224,
#        'lng': -0.1268028951415381}],
#      'distance': 355,
#      'postalCode': 'WC2N 4EJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["42 - 49 St Martin's Lane",
#       'London',
#       'Greater London',
#       'WC2N 4EJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4c6ad76b96eaa5932f0c21df',
#     'name': 'Nuffield Health Fitness & Wellbeing Gym',
#     'location': {'address': 'Mecklenburgh Place',
#      'lat': 51.524178,
#      'lng': -0.118479,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.524178,
#        'lng': -0.118479}],
#      'distance': 1980,
#      'postalCode': 'WC1N 2AY',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Mecklenburgh Place',
#       'London',
#       'Greater London',
#       'WC1N 2AY',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4f45eab8e4b07a632968495a',
#     'name': 'The Gym',
#     'location': {'address': 'at The Cumberland Hotel',
#      'lat': 51.513928325635966,
#      'lng': -0.1581007856766829,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.513928325635966,
#        'lng': -0.1581007856766829}],
#      'distance': 2234,
#      'postalCode': 'W1C 1LZ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['at The Cumberland Hotel',
#       'London',
#       'Greater London',
#       'W1C 1LZ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '50d1e4f7e4b0e8c315cb672d',
#     'name': 'Google Gym',
#     'location': {'address': '123 Buckingham Palace Road',
#      'lat': 51.49384434052192,
#      'lng': -0.14687349466438465,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49384434052192,
#        'lng': -0.14687349466438465}],
#      'distance': 2006,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['123 Buckingham Palace Road',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4fa24723e4b018dc45f00c96',
#     'name': 'LSBU Gym',
#     'location': {'address': 'London South Bank University',
#      'lat': 51.49765441597138,
#      'lng': -0.10308480264070155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49765441597138,
#        'lng': -0.10308480264070155}],
#      'distance': 2013,
#      'cc': 'GB',
#      'city': 'Greater London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London South Bank University',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5601b040498e5def6d164bc6',
#     'name': 'Amba Hotel Gym',
#     'location': {'lat': 51.50831237866142,
#      'lng': -0.12466883213699784,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50831237866142,
#        'lng': -0.12466883213699784}],
#      'distance': 233,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5707d85a498e119ec0c721e5',
#     'name': 'PureGym',
#     'location': {'address': 'Rex House, 4-12 Regent St',
#      'lat': 51.50853361351264,
#      'lng': -0.1335231726655443,
#      'distance': 428,
#      'postalCode': 'SW1Y 4PE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Rex House, 4-12 Regent St',
#       'London',
#       'Greater London',
#       'SW1Y 4PE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5a0eea7964c8e11593989ebd',
#     'name': 'Gym @ Every Hotel Piccadilly',
#     'location': {'lat': 51.510223,
#      'lng': -0.13155565,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510223,
#        'lng': -0.13155565}],
#      'distance': 421,
#      'postalCode': 'W1D',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'W1D',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '50089c99e4b04645579577b1',
#     'name': 'Sofitel Gym (SoFit)',
#     'location': {'address': 'at Sofitel London St James',
#      'lat': 51.5077958036034,
#      'lng': -0.13238870485405554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5077958036034,
#        'lng': -0.13238870485405554}],
#      'distance': 332,
#      'postalCode': 'SW1Y 4AN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['at Sofitel London St James',
#       'London',
#       'Greater London',
#       'SW1Y 4AN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '568b7a1f498ec3ce2080bf90',
#     'name': "Bain's Gym",
#     'location': {'address': '40 Strand',
#      'lat': 51.509177,
#      'lng': -0.123955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.509177,
#        'lng': -0.123955}],
#      'distance': 328,
#      'postalCode': 'WC2N 5RW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['40 Strand',
#       'London',
#       'Greater London',
#       'WC2N 5RW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5c61397ce55d8b0039e68a1a',
#     'name': 'Embassy Gardens Legacy Gym',
#     'location': {'address': '1 Viaduct Gardens',
#      'lat': 51.482051,
#      'lng': -0.130603,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.482051,
#        'lng': -0.130603}],
#      'distance': 2820,
#      'postalCode': 'SW11 7AY',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Viaduct Gardens',
#       'London',
#       'Greater London',
#       'SW11 7AY',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4ad2501af964a520dbe020e3',
#     'name': 'Nuffield Health Fitness & Wellbeing Gym',
#     'location': {'address': '4 Cousin Ln',
#      'lat': 51.50990028472117,
#      'lng': -0.0911945188189489,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50990028472117,
#        'lng': -0.0911945188189489}],
#      'distance': 2541,
#      'postalCode': 'EC4R 3XJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['4 Cousin Ln',
#       'London',
#       'Greater London',
#       'EC4R 3XJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4f147d2fe4b0678413d46d0b',
#     'name': 'Lloyds Banking Group Gym',
#     'location': {'address': '10 Gresham St, City of London, London EC2V',
#      'lat': 51.51556643060581,
#      'lng': -0.09490728378295897,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51556643060581,
#        'lng': -0.09490728378295897}],
#      'distance': 2446,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 Gresham St, City of London, London EC2V',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5bcdb5367dc9e1002c781301',
#     'name': 'Deliveroo Gym',
#     'location': {'address': '1 Cousin Lane',
#      'lat': 51.510045,
#      'lng': -0.091185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510045,
#        'lng': -0.091185}],
#      'distance': 2544,
#      'postalCode': 'EC4R 3XJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Cousin Lane',
#       'London',
#       'Greater London',
#       'EC4R 3XJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '54a708cd498e9722fa507bb5',
#     'name': 'The Gym',
#     'location': {'address': '265-269 Goswell Road',
#      'lat': 51.53002,
#      'lng': -0.10314703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53002,
#        'lng': -0.10314703}],
#      'distance': 3043,
#      'postalCode': 'EC1V 7AH',
#      'cc': 'GB',
#      'neighborhood': 'Islington',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['265-269 Goswell Road',
#       'London',
#       'Greater London',
#       'EC1V 7AH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5c081dd7dab4b100394d0f29',
#     'name': 'The Gym',
#     'location': {'address': 'Swan Ln',
#      'lat': 51.509186,
#      'lng': -0.08468907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.509186,
#        'lng': -0.08468907}],
#      'distance': 2983,
#      'postalCode': 'EC4R 3TR',
#      'cc': 'GB',
#      'neighborhood': 'Billingsgate',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Swan Ln',
#       'London',
#       'Greater London',
#       'EC4R 3TR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4ac518f8f964a52007b020e3',
#     'name': 'Cally Pool & Gym',
#     'location': {'address': '229 Caledonian Rd',
#      'lat': 51.538550377291976,
#      'lng': -0.1166270741000282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.538550377291976,
#        'lng': -0.1166270741000282}],
#      'distance': 3559,
#      'postalCode': 'N1 0NH',
#      'cc': 'GB',
#      'neighborhood': 'Caledonian',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['229 Caledonian Rd',
#       'London',
#       'Greater London',
#       'N1 0NH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5e10c7e512352500087ef4d7',
#     'name': 'The Army Gym, Nigel Cabourn',
#     'location': {'lat': 51.511096,
#      'lng': -0.123887,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.511096,
#        'lng': -0.123887}],
#      'distance': 494,
#      'postalCode': 'WC2E 8NA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'WC2E 8NA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4f4ccf93e4b03af95ffa70d6',
#     'name': "Regent's College Gym",
#     'location': {'address': "Regent's College",
#      'crossStreet': 'Inner Circle',
#      'lat': 51.52583745397272,
#      'lng': -0.15542840797387075,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52583745397272,
#        'lng': -0.15542840797387075}],
#      'distance': 2819,
#      'postalCode': 'NW1 4NS',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["Regent's College (Inner Circle)",
#       'London',
#       'Greater London',
#       'NW1 4NS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '50ed1ee9e4b0142ae7e0e8d8',
#     'name': 'Gym and Pool at One Aldwych',
#     'location': {'address': 'One Aldwych',
#      'lat': 51.51167989893346,
#      'lng': -0.11937306045507355,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51167989893346,
#        'lng': -0.11937306045507355}],
#      'distance': 750,
#      'postalCode': 'WC2B 4BZ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['One Aldwych',
#       'London',
#       'Greater London',
#       'WC2B 4BZ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4cce72af566aa093f3582dfd',
#     'name': 'The Gym & Club at County Hall',
#     'location': {'address': 'County Hall',
#      'crossStreet': 'Belvedere Road',
#      'lat': 51.502078935344265,
#      'lng': -0.1197390872672625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.502078935344265,
#        'lng': -0.1197390872672625}],
#      'distance': 800,
#      'postalCode': 'SE1 7PB',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['County Hall (Belvedere Road)',
#       'London',
#       'Greater London',
#       'SE1 7PB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4ee080c9b8f741383055ed5b',
#     'name': 'Gym@102',
#     'location': {'address': '102 Petty France',
#      'lat': 51.49987410415896,
#      'lng': -0.1321355005739727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49987410415896,
#        'lng': -0.1321355005739727}],
#      'distance': 885,
#      'postalCode': 'SW1',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['102 Petty France',
#       'London',
#       'Greater London',
#       ' SW1',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '59541fbc9ef8ef439e3f6c04',
#     'name': 'Gym @ Me London Hotel',
#     'location': {'lat': 51.511726,
#      'lng': -0.118249,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.511726,
#        'lng': -0.118249}],
#      'distance': 815,
#      'postalCode': 'W C2R',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'W C2R',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4cdafd1f4006a1430571d5b2',
#     'name': 'Westminster Gym',
#     'location': {'address': 'Derby Gate, 1 Canon Row',
#      'lat': 51.501859293004934,
#      'lng': -0.12498855685455555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.501859293004934,
#        'lng': -0.12498855685455555}],
#      'distance': 635,
#      'postalCode': 'SW1A 2JN',
#      'cc': 'GB',
#      'city': 'City of Westminster',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Derby Gate, 1 Canon Row',
#       'City of Westminster',
#       'Greater London',
#       'SW1A 2JN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4e4fed0da80997aa8a3fd909',
#     'name': 'Le Méridien Gym and Spa',
#     'location': {'address': '21 Piccadilly',
#      'lat': 51.50934374075219,
#      'lng': -0.13639083030256796,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50934374075219,
#        'lng': -0.13639083030256796}],
#      'distance': 646,
#      'postalCode': 'W1J OBH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['21 Piccadilly',
#       'London',
#       'Greater London',
#       'W1J OBH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '50eb1154e4b0541e75c25274',
#     'name': "Strand Palace Hotel's Gym",
#     'location': {'lat': 51.51089772999349,
#      'lng': -0.12098978003190446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51089772999349,
#        'lng': -0.12098978003190446}],
#      'distance': 609,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5e5cfc9c9f640c00073083b6',
#     'name': 'Jack Solomons Gym',
#     'location': {'address': '41 Great Windmill Street',
#      'lat': 51.51098005968945,
#      'lng': -0.13405680656433105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51098005968945,
#        'lng': -0.13405680656433105}],
#      'distance': 602,
#      'postalCode': 'W1D 7NB',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['41 Great Windmill Street',
#       'London',
#       'Greater London',
#       'W1D 7NB',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b47',
#       'name': 'Boxing Gym',
#       'pluralName': 'Boxing Gyms',
#       'shortName': 'Boxing Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5818a6f0d67c176bc1e450c2',
#     'name': '6PS Gym',
#     'location': {'address': '6 Pancras Sq',
#      'lat': 51.533246112507435,
#      'lng': -0.12575711702937123,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.533246112507435,
#        'lng': -0.12575711702937123}],
#      'distance': 2888,
#      'postalCode': 'N1C 4AG',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['6 Pancras Sq',
#       'London',
#       'Greater London',
#       'N1C 4AG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '58a43e1f24ca6a51235842e6',
#     'name': 'Gym Clobber',
#     'location': {'address': 'DW Sports Fitness Waldorf Aldwych',
#      'lat': 51.512750515941526,
#      'lng': -0.11885665026238712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.512750515941526,
#        'lng': -0.11885665026238712}],
#      'distance': 857,
#      'postalCode': 'WC2B 4DD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['DW Sports Fitness Waldorf Aldwych',
#       'London',
#       'Greater London',
#       'WC2B 4DD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1f2941735',
#       'name': 'Sporting Goods Shop',
#       'pluralName': 'Sporting Goods Shops',
#       'shortName': 'Sporting Goods',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '397984078'},
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '5753de7a498ecf0185df0592',
#     'name': 'Ham Yard Hotel Gym',
#     'location': {'lat': 51.510994,
#      'lng': -0.134826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510994,
#        'lng': -0.134826}],
#      'distance': 643,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '4eb6bf386c2590eb889a782b',
#     'name': 'Jubilee Hall Gym',
#     'location': {'address': '30 The Piazza',
#      'lat': 51.51195611025909,
#      'lng': -0.12210762544716137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51195611025909,
#        'lng': -0.12210762544716137}],
#      'distance': 642,
#      'postalCode': 'WC2 8BE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['30 The Piazza',
#       'London',
#       'Greater London',
#       'WC2 8BE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False},
#    {'id': '564defc5498e348064a471a7',
#     'name': 'Nuffield Health Fitness & Wellbeing Gym',
#     'location': {'address': '1 Ropemaker St',
#      'lat': 51.519532320844064,
#      'lng': -0.0895652005018377,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.519532320844064,
#        'lng': -0.0895652005018377}],
#      'distance': 2967,
#      'postalCode': 'EC2Y 9AW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Ropemaker St',
#       'London',
#       'Greater London',
#       'EC2Y 9AW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591266065',
#     'hasPerk': False}]}}

# %% [markdown]
# #### From this API we call extracted the following data:
#
# - Location
# - Postal code
# - Restaurant name
# - Restaurant category
# - Location ID

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /Users/joseph_arber/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                          name  \
# 0  55118ea6498e10c0a61edfa4  The Gym London Charing Cross
# 1  503a6e8be4b0bd2ec5157d9b                 ESPA Life Gym
# 2  5881e9efcc5b6a08df5a8768              Radisson Blu Gym
# 3  56fe22b0498ef2d2226413fb             FIT (W Hotel Gym)
# 4  4bfc141da118a59336ee6db6                       The Gym
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1591266065    False
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1591266065    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1591266065    False
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1591266065    False
# 4  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1591266065    False
#
#                 location.address  location.lat  location.lng  \
# 0       17-21 Northumberland Ave     51.507019     -0.124760
# 1                10 Whitehall Pl     51.506318     -0.124648
# 2             31-36 Leicester Sq     51.509950     -0.129873
# 3                            NaN     51.510029     -0.131398
# 4  30 The Piazza London WC2E 8BE     51.511862     -0.121950
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.50701872318441...                202
# 1  [{'label': 'display', 'lat': 51.50631843415083...                235
# 2  [{'label': 'display', 'lat': 51.50995, 'lng': ...                330
# 3  [{'label': 'display', 'lat': 51.51002945140006...                397
# 4  [{'label': 'display', 'lat': 51.51186222602245...                641
#
#   location.postalCode location.cc   location.city  location.state  \
# 0            WC2N 5EA          GB  City of London  Greater London
# 1                 NaN          GB          London  Greater London
# 2            WC2H 7LH          GB          London  Greater London
# 3                 NaN          GB          London  Greater London
# 4                 NaN          GB          London  Greater London
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [17-21 Northumberland Ave, City of London, Gre...
# 1   United Kingdom  [10 Whitehall Pl, London, Greater London, Unit...
# 2   United Kingdom  [31-36 Leicester Sq, London, Greater London, W...
# 3   United Kingdom           [London, Greater London, United Kingdom]
# 4   United Kingdom  [30 The Piazza London WC2E 8BE, London, Greate...
#
#   location.crossStreet location.neighborhood venuePage.id
# 0                  NaN                   NaN          NaN
# 1                  NaN                   NaN          NaN
# 2                  NaN                   NaN          NaN
# 3                  NaN                   NaN          NaN
# 4                  NaN                   NaN          NaN

# %%
#Neighbourhoods = list(dataframe.columns.values)
#Neighbourhoods = Neighbourhoods[5:]
#print(Neighbourhoods)
# Out:
# []

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head(20)
# Out:
#                                        name            categories  \
# 0              The Gym London Charing Cross  Gym / Fitness Center
# 1                             ESPA Life Gym                   Gym
# 2                          Radisson Blu Gym                   Gym
# 3                         FIT (W Hotel Gym)  Gym / Fitness Center
# 4                                   The Gym  Gym / Fitness Center
# 5                  The Gym @ LikeMinds Club                   Gym
# 6   Nuffield Health Fitness & Wellbeing Gym                   Gym
# 7                          The May Fair Gym                   Gym
# 8                 Lansdowne Club Gym & Pool                   Gym
# 9                           The Belmont Gym  Gym / Fitness Center
# 10                                  The Gym  Gym / Fitness Center
# 11                                  The Gym                   Gym
# 12                               Regent Gym                   Gym
# 13                        Club Quarters Gym  Gym / Fitness Center
# 14                                  The Gym                   Gym
# 15                    The Gym Charing Cross                   Gym
# 16                           Park Plaza Gym                   Gym
# 17                        Goldman Sachs Gym                   Gym
# 18                                   Gymbox  Gym / Fitness Center
# 19  Nuffield Health Fitness & Wellbeing Gym                   Gym
#
#                                  address        lat       lng  \
# 0               17-21 Northumberland Ave  51.507019 -0.124760
# 1                        10 Whitehall Pl  51.506318 -0.124648
# 2                     31-36 Leicester Sq  51.509950 -0.129873
# 3                                    NaN  51.510029 -0.131398
# 4          30 The Piazza London WC2E 8BE  51.511862 -0.121950
# 5                     Northumberland Ave  51.507319 -0.127489
# 6                        9 Endell Street  51.514156 -0.123908
# 7                     The May Fair Hotel  51.508483 -0.144305
# 8                    9 Fitzmaurice Place  51.508306 -0.145273
# 9   1st. Floor, Embassy Garden Residence  51.482081 -0.134500
# 10        195-203 Waterloo Rd, Barons Pl  51.500731 -0.107099
# 11                   6A St. George Wharf  51.485305 -0.126244
# 12                         309 Regent St  51.516926 -0.142628
# 13                                   NaN  51.506967 -0.126048
# 14                   332-334 Walworth Rd  51.485818 -0.094187
# 15           17-21 Northumberland Avenue  51.507042 -0.124865
# 16                239 Vauxhall Bridge Rd  51.494123 -0.141674
# 17                        Plumtree Court  51.516312 -0.105678
# 18              42 - 49 St Martin's Lane  51.510468 -0.126803
# 19                    Mecklenburgh Place  51.524178 -0.118479
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 51.50701872318441...       202   WC2N 5EA
# 1   [{'label': 'display', 'lat': 51.50631843415083...       235        NaN
# 2   [{'label': 'display', 'lat': 51.50995, 'lng': ...       330   WC2H 7LH
# 3   [{'label': 'display', 'lat': 51.51002945140006...       397        NaN
# 4   [{'label': 'display', 'lat': 51.51186222602245...       641        NaN
# 5   [{'label': 'display', 'lat': 51.5073187453107,...        10        NaN
# 6   [{'label': 'display', 'lat': 51.51415625004893...       803   WC2H 9SA
# 7   [{'label': 'display', 'lat': 51.50848296133080...      1161    W1J 8LT
# 8   [{'label': 'display', 'lat': 51.50830561713405...      1226    WIJ 5JD
# 9   [{'label': 'display', 'lat': 51.482081, 'lng':...      2849        SW8
# 10  [{'label': 'display', 'lat': 51.50073064127175...      1601    SE1 8UX
# 11  [{'label': 'display', 'lat': 51.48530506481089...      2452    SW8 2LE
# 12  [{'label': 'display', 'lat': 51.51692587106962...      1490    W1B 2UW
# 13  [{'label': 'display', 'lat': 51.5069665287522,...       117        NaN
# 14  [{'label': 'display', 'lat': 51.48581815433415...      3332   SE17 2NA
# 15  [{'label': 'display', 'lat': 51.50704192570248...       195      W C2N
# 16  [{'label': 'display', 'lat': 51.49412316413798...      1761   SW1V 1EQ
# 17  [{'label': 'display', 'lat': 51.516312, 'lng':...      1821   EC4A 4AU
# 18  [{'label': 'display', 'lat': 51.5104680522224,...       355   WC2N 4EJ
# 19  [{'label': 'display', 'lat': 51.524178, 'lng':...      1980   WC1N 2AY
#
#     cc            city           state         country  \
# 0   GB  City of London  Greater London  United Kingdom
# 1   GB          London  Greater London  United Kingdom
# 2   GB          London  Greater London  United Kingdom
# 3   GB          London  Greater London  United Kingdom
# 4   GB          London  Greater London  United Kingdom
# 5   GB          London  Greater London  United Kingdom
# 6   GB          London  Greater London  United Kingdom
# 7   GB         Mayfair  Greater London  United Kingdom
# 8   GB          London  Greater London  United Kingdom
# 9   GB          London  Greater London  United Kingdom
# 10  GB          London  Greater London  United Kingdom
# 11  GB          London  Greater London  United Kingdom
# 12  GB          London  Greater London  United Kingdom
# 13  GB             NaN             NaN  United Kingdom
# 14  GB   East Walworth  Greater London  United Kingdom
# 15  GB          London  Greater London  United Kingdom
# 16  GB          London  Greater London  United Kingdom
# 17  GB          London  Greater London  United Kingdom
# 18  GB          London  Greater London  United Kingdom
# 19  GB          London  Greater London  United Kingdom
#
#                                      formattedAddress     crossStreet  \
# 0   [17-21 Northumberland Ave, City of London, Gre...             NaN
# 1   [10 Whitehall Pl, London, Greater London, Unit...             NaN
# 2   [31-36 Leicester Sq, London, Greater London, W...             NaN
# 3            [London, Greater London, United Kingdom]             NaN
# 4   [30 The Piazza London WC2E 8BE, London, Greate...             NaN
# 5   [Northumberland Ave, London, Greater London, U...             NaN
# 6   [9 Endell Street, London, Greater London, WC2H...             NaN
# 7   [The May Fair Hotel (Stratton St), Mayfair, Gr...     Stratton St
# 8   [9 Fitzmaurice Place, London, Greater London, ...             NaN
# 9   [1st. Floor, Embassy Garden Residence (Nine El...  Nine Elms Lane
# 10  [195-203 Waterloo Rd, Barons Pl, London, Great...             NaN
# 11  [6A St. George Wharf (Wandsworth Rd), London, ...   Wandsworth Rd
# 12  [309 Regent St, London, Greater London, W1B 2U...             NaN
# 13                                   [United Kingdom]             NaN
# 14  [332-334 Walworth Rd, East Walworth, Greater L...             NaN
# 15  [17-21 Northumberland Avenue, London, Greater ...             NaN
# 16  [239 Vauxhall Bridge Rd, London, Greater Londo...             NaN
# 17  [Plumtree Court, London, Greater London, EC4A ...             NaN
# 18  [42 - 49 St Martin's Lane, London, Greater Lon...             NaN
# 19  [Mecklenburgh Place, London, Greater London, W...             NaN
#
#    neighborhood                        id
# 0           NaN  55118ea6498e10c0a61edfa4
# 1           NaN  503a6e8be4b0bd2ec5157d9b
# 2           NaN  5881e9efcc5b6a08df5a8768
# 3           NaN  56fe22b0498ef2d2226413fb
# 4           NaN  4bfc141da118a59336ee6db6
# 5           NaN  4f057f256c25095786d949e4
# 6           NaN  4ae4991ff964a520259c21e3
# 7           NaN  54c89520498e5d7951c9dd48
# 8           NaN  518cae33498e8c38baca3946
# 9           NaN  580629ca38fa9251426bce25
# 10          NaN  4feae9c464a4fa28dce56e53
# 11          NaN  4b83313bf964a520c1fc30e3
# 12          NaN  4c48029c0f5aa593a2d67f76
# 13          NaN  54446d45498ef5d7f4f4cfcf
# 14          NaN  4ba5fcadf964a520e82c39e3
# 15          NaN  551e56e2498e16bdb3df38c3
# 16          NaN  50da22c4e4b0be098804c1db
# 17          NaN  5d7b8e3725670800086cdd9c
# 18          NaN  4adc54a0f964a520bc2b21e3
# 19          NaN  4c6ad76b96eaa5932f0c21df

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent Trafalgar Square
folium.features.CircleMarker(
    [latitude, longitude],
    radius=15,
    color='red',
    popup='Trafalgar Square',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered.shape
# Out:
# (50, 16)

# %%
dataframe_filtered.dtypes
# Out:
# name                 object
# categories           object
# address              object
# lat                 float64
# lng                 float64
# labeledLatLngs       object
# distance              int64
# postalCode           object
# cc                   object
# city                 object
# state                object
# country              object
# formattedAddress     object
# crossStreet          object
# neighborhood         object
# id                   object
# dtype: object

# %%
venue_id = '55118ea6498e10c0a61edfa4' # ID of the Gym Charing Cross
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/55118ea6498e10c0a61edfa4?client_id=K2D5QVKQ0QPUPIKECQU2JIB3CHVFT4ZMTJQC5WVTRNYTDD5Z&client_secret=5ZVFLDC04W0W5SHCBZ11MDRG0MELPIER3QIFUOAWFAIZKJNK&v=20200808'

# %%
result = requests.get(url).json()
result
# Out:
# {'meta': {'code': 200, 'requestId': '5ed8cbde1a4b0a001b4321fe'},
#  'response': {'venue': {'id': '55118ea6498e10c0a61edfa4',
#    'name': 'The Gym London Charing Cross',
#    'contact': {'phone': '+443300553926', 'formattedPhone': '+44 330 055 3926'},
#    'location': {'address': '17-21 Northumberland Ave',
#     'lat': 51.50701872318441,
#     'lng': -0.12476041859239369,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.50701872318441,
#       'lng': -0.12476041859239369}],
#     'postalCode': 'WC2N 5EA',
#     'cc': 'GB',
#     'city': 'City of London',
#     'state': 'Greater London',
#     'country': 'United Kingdom',
#     'formattedAddress': ['17-21 Northumberland Ave',
#      'City of London',
#      'Greater London',
#      'WC2N 5EA',
#      'United Kingdom']},
#    'canonicalUrl': 'https://foursquare.com/v/the-gym-london-charing-cross/55118ea6498e10c0a61edfa4',
#    'categories': [{'id': '4bf58dd8d48988d175941735',
#      'name': 'Gym / Fitness Center',
#      'pluralName': 'Gyms or Fitness Centers',
#      'shortName': 'Gym / Fitness',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'},
#      'primary': True},
#     {'id': '4bf58dd8d48988d176941735',
#      'name': 'Gym',
#      'pluralName': 'Gyms',
#      'shortName': 'Gym',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'}}],
#    'verified': False,
#    'stats': {'tipCount': 3},
#    'url': 'https://www.thegymgroup.com/find-a-gym/charing-cross/',
#    'likes': {'count': 3,
#     'groups': [{'type': 'others',
#       'count': 3,
#       'items': [{'id': '5720800',
#         'firstName': 'Anu',
#         'lastName': 'A',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/5720800-C25LVDUVPBXDUPUU.jpg'}},
#        {'id': '3986378',
#         'firstName': 'Dave',
#         'lastName': 'M',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/3986378_6f6kmk9u_89ylRKbEuWFUtVWKp5sCfJ81A7Eci7YIUWWxIZFf_k5aAPT6rx7MP4RrCU8fQSqe.jpg'}},
#        {'id': '3148892',
#         'firstName': 'Nigel',
#         'lastName': 'G',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/OFHGO1MBQALLZYB3.jpg'}}]}],
#     'summary': '3 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 6.2,
#    'ratingColor': 'FFC800',
#    'ratingSignals': 8,
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 1,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 1,
#       'items': [{'id': '59975272f8cbd46f1c226a06',
#         'createdAt': 1503089266,
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#         'width': 3888,
#         'height': 2592,
#         'user': {'id': '212169387',
#          'firstName': 'pivot_photos',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/blank_boy.png',
#           'default': True},
#          'type': 'page'},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 0, 'items': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1427213990,
#    'tips': {'count': 3,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 3,
#       'items': [{'id': '568ab264498e732703eaf44b',
#         'createdAt': 1451930212,
#         'text': 'Great value gym.  Get down early for the best time.',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/568ab264498e732703eaf44b',
#         'lang': 'en',
#         'likes': {'count': 1,
#          'groups': [{'type': 'others',
#            'count': 1,
#            'items': [{'id': '3986378',
#              'firstName': 'Dave',
#              'lastName': 'M',
#              'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#               'suffix': '/3986378_6f6kmk9u_89ylRKbEuWFUtVWKp5sCfJ81A7Eci7YIUWWxIZFf_k5aAPT6rx7MP4RrCU8fQSqe.jpg'}}]}],
#          'summary': '1 like'},
#         'logView': True,
#         'agreeCount': 1,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'id': '3986378',
#          'firstName': 'Dave',
#          'lastName': 'M',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/3986378_6f6kmk9u_89ylRKbEuWFUtVWKp5sCfJ81A7Eci7YIUWWxIZFf_k5aAPT6rx7MP4RrCU8fQSqe.jpg'}},
#         'authorInteractionType': 'liked'}]}]},
#    'shortUrl': 'http://4sq.com/1Bp5dAL',
#    'timeZone': 'Europe/London',
#    'listed': {'count': 0,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 0,
#       'items': []}]},
#    'hours': {'status': 'Open until 10:00 PM',
#     'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#     'isOpen': True,
#     'isLocalHoliday': False,
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Fri',
#       'includesToday': True,
#       'open': [{'renderedTime': '6:00 AM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Sat–Sun',
#       'open': [{'renderedTime': '10:00 AM–5:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'defaultHours': {'status': 'Open until 10:00 PM',
#     'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#     'isOpen': True,
#     'isLocalHoliday': False,
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Fri',
#       'includesToday': True,
#       'open': [{'renderedTime': '6:00 AM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Sat–Sun',
#       'open': [{'renderedTime': '10:00 AM–5:00 PM'}],
#       'segments': []}]},
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': []},
#    'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#     'createdAt': 1503089266,
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#     'width': 3888,
#     'height': 2592,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#      'value': -14145480},
#     'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#     'algoVersion': 3}}}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.2

# %%
venue_id = '503a6e8be4b0bd2ec5157d9b' # ID of ESPA life gym
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.3

# %%
venue_id = '580629ca38fa9251426bce25' # The Belmont Gym
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
result['response']['venue']['tips']['count']
# Out:
# 0

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed8d0bbedbcad0023adc622'},
#  'response': {'tips': {'count': 0, 'items': []}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-13fe61f140cf> in <module>
#       1 tips = results['response']['tips']['items']
#       2
# ----> 3 tip = results['response']['tips']['items'][0]
#       4 tip.keys()
#
# IndexError: list index out of range

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# /Users/joseph_arber/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
# /Users/joseph_arber/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-fe9c7711676c> in <module>
#       5 # columns to keep
#       6 filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
# ----> 7 tips_filtered = tips_df.loc[:, filtered_columns]
#       8
#       9 # display tips
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName',\n       'user.lastName', 'user.gender', 'user.id'],\n      dtype='object')] are in the [columns]"
